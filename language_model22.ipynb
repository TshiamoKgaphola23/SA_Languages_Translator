# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Bidirectional, LSTM, Dense, Dropout
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report

# %%
# Loading my dataset 
ds = pd.read_csv('/Users/damacm1143/Downloads/SA_official_languages.csv')

# %%
ds
# Out:
#       lang_id                                               text
# 0         xho  umgaqo-siseko wenza amalungiselelo kumaziko ax...
# 1         xho  i-dha iya kuba nobulumko bokubeka umsebenzi na...
# 2         eng  the province of kwazulu-natal department of tr...
# 3         nso  o netefatša gore o ba file dilo ka moka tše le...
# 4         ven  khomishini ya ndinganyiso ya mbeu yo ewa maana...
# ...       ...                                                ...
# 32995     tsn  popo ya dipolateforomo tse ke go tlisa boetele...
# 32996     sot  modise mosadi na o ntse o sa utlwe hore thaban...
# 32997     eng  closing date for the submission of completed t...
# 32998     xho  nawuphina umntu ofunyenwe enetyala phantsi kwa...
# 32999     sot  mafapha a mang le ona a lokela ho etsa ditlale...
#
# [33000 rows x 2 columns]

# %%
ds['lang_id'].value_counts()
# Out:
# lang_id
# xho    3000
# eng    3000
# nso    3000
# ven    3000
# tsn    3000
# nbl    3000
# zul    3000
# ssw    3000
# tso    3000
# sot    3000
# afr    3000
# Name: count, dtype: int64

# %%
# Distribution of characters for each language
char_counts = ds['text'].apply(lambda x: pd.Series(list(x))).stack().value_counts()
print(char_counts)

# Character frequency for each language
char_freq_per_lang = ds.groupby('lang_id')['text'].apply(lambda x: ''.join(x)).apply(lambda x: pd.Series(list(x)).value_counts())
print(char_freq_per_lang)
# Out:
#      1192280
# a     907551
# e     763846
# i     525770
# o     517527
#       ...
# ˜          1
# ¢          1
# à          1
#           1
# ±          1
# Name: count, Length: 94, dtype: int64
#                           e        i        n         a        r        s  \
# lang_id
# afr      114856.0  107523.0  55324.0  52452.0   49657.0  42102.0  39295.0
# eng      117700.0   76046.0  49640.0  47932.0   49299.0  41457.0  39123.0
# nbl       74238.0   66240.0  54086.0  57271.0   89402.0   4366.0  21148.0
# nso      132758.0   74385.0  26054.0  22457.0   92480.0  11509.0  13929.0
# sot      134202.0   80717.0  23177.0  33305.0   96002.0   9216.0  36022.0
# ssw       75957.0   76149.0  57159.0  55349.0   77857.0   1177.0  30641.0
# tsn      131791.0   70927.0  31063.0  31495.0   91651.0  13609.0  33526.0
# tso      125327.0   43596.0  64226.0  47274.0   98455.0  14132.0  22707.0
# ven      129784.0   35922.0  48688.0  39765.0  103130.0   8604.0  24922.0
# xho       78880.0   66044.0  55721.0  56699.0   80954.0   2024.0  22932.0
# zul       76787.0   66297.0  60632.0  56902.0   78664.0   1092.0  25211.0
#
#                o        d        t  ...    ¿    ²    ¦    †    ‚    ƒ    ¯  \
# lang_id                             ...
# afr      38296.0  35764.0  34559.0  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# eng      48382.0  22252.0  60301.0  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# nbl      43278.0   9040.0  18876.0  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# nso      73925.0  13110.0  35610.0  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# sot      63257.0  10327.0  40637.0  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ssw      30241.0   8287.0  33954.0  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# tsn      68715.0  14315.0  42563.0  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# tso      30071.0   8312.0  21269.0  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ven      33431.0  18612.0  21074.0  ...  3.0  1.0  NaN  NaN  NaN  NaN  NaN
# xho      46104.0   7461.0  15448.0  ...  NaN  NaN  2.0  2.0  NaN  NaN  NaN
# zul      41827.0   8467.0  15439.0  ...  NaN  NaN  NaN  NaN  4.0  2.0  2.0
#
#            ¢    å    ¸
# lang_id
# afr      NaN  NaN  NaN
# eng      NaN  NaN  NaN
# nbl      NaN  NaN  NaN
# nso      NaN  NaN  NaN
# sot      NaN  NaN  NaN
# ssw      NaN  NaN  NaN
# tsn      NaN  NaN  NaN
# tso      NaN  NaN  NaN
# ven      NaN  NaN  NaN
# xho      NaN  NaN  NaN
# zul      1.0  1.0  1.0
#
# [11 rows x 94 columns]

# %%
from sklearn.feature_extraction.text import CountVectorizer

# Function to get top N-grams
def get_top_ngrams(corpus, n=2, top_k=10):
    vec = CountVectorizer(ngram_range=(n, n)).fit(corpus)
    bag_of_words = vec.transform(corpus)
    sum_words = bag_of_words.sum(axis=0)
    words_freq = [(word, sum_words[0, idx]) for word, idx in vec.vocabulary_.items()]
    words_freq = sorted(words_freq, key=lambda x: x[1], reverse=True)
    return words_freq[:top_k]

# Get top bigrams for each language
for lang in ds['lang_id'].unique():
    texts = ds[ds['lang_id'] == lang]['text']
    print(f"Top bigrams in {lang}:")
    print(get_top_ngrams(texts, n=2))
# Out:
# Top bigrams in xho:
# [('emzantsi afrika', 76), ('ukuba ngaba', 59), ('phambi kokuba', 53), ('ngaphandle kokuba', 49), ('nayiphi na', 48), ('bomzantsi afrika', 46), ('emva kokuba', 45), ('okanye ke', 39), ('nawuphi na', 38), ('ukuqinisekisa ukuba', 36)]
# Top bigrams in eng:
# [('of the', 1901), ('in the', 760), ('to the', 671), ('by the', 420), ('for the', 398), ('and the', 379), ('terms of', 299), ('with the', 292), ('on the', 288), ('in terms', 288)]
# Top bigrams in nso:
# [('le go', 761), ('ka go', 675), ('ya go', 577), ('swanetše go', 517), ('go ya', 429), ('tšeo di', 411), ('ya ka', 406), ('tše di', 395), ('tša go', 340), ('na le', 328)]
# Top bigrams in ven:
# [('vha na', 435), ('vha tshi', 341), ('afrika tshipembe', 320), ('mulayo wa', 282), ('kha vha', 280), ('ine ya', 269), ('tshi khou', 263), ('hu tshi', 244), ('ya nga', 240), ('vha nga', 239)]
# Top bigrams in tsn:
# [('tse di', 1182), ('le go', 749), ('tshwanetse go', 549), ('go ya', 497), ('ya go', 442), ('ba ba', 357), ('se se', 355), ('ya ka', 348), ('mo go', 335), ('na le', 327)]
# Top bigrams in nbl:
# [('kufuze bona', 111), ('esewula afrika', 71), ('omunye nomunye', 56), ('yesewula afrika', 56), ('kungakapheli amalanga', 47), ('umthetho wenomboro', 43), ('ngaphambi kobana', 41), ('ophathelene nalokhu', 38), ('umthetho ka', 37), ('isiqiniseko sokobana', 34)]
# Top bigrams in zul:
# [('eningizimu afrika', 64), ('kwalo mthetho', 37), ('ngaphambi kokuba', 32), ('ngaphandle uma', 32), ('ngaphansi kwesigaba', 32), ('ofake isicelo', 31), ('ka umthetho', 31), ('lowo muntu', 30), ('uma ngabe', 28), ('ngakho ke', 28)]
# Top bigrams in ssw:
# [('uma ngabe', 179), ('eningizimu afrika', 75), ('nobe ngabe', 47), ('kufaka ekhatsi', 39), ('kuto tonkhe', 34), ('kantsi futsi', 33), ('baseningizimu afrika', 33), ('wonkhe umuntfu', 32), ('siciniseko sekutsi', 30), ('ngako ke', 28)]
# Top bigrams in tso:
# [('hi ku', 810), ('fanele ku', 594), ('na ku', 500), ('ku va', 359), ('ku ya', 355), ('ku nga', 275), ('kumbe ku', 275), ('xiyenge xa', 265), ('ya hi', 248), ('swi nga', 244)]
# Top bigrams in sot:
# [('le ho', 704), ('ka ho', 413), ('bakeng sa', 394), ('ya ho', 316), ('lokela ho', 313), ('ha ho', 309), ('na le', 269), ('ho ya', 260), ('ya ka', 256), ('jwalo ka', 256)]
# Top bigrams in afr:
# [('van die', 1774), ('in die', 824), ('vir die', 408), ('en die', 364), ('aan die', 342), ('om die', 312), ('op die', 307), ('by die', 287), ('deur die', 285), ('met die', 284)]

# %%
# # Separating sentences and labels
# X = ds['text'].values
# y = ds['lang_id'].values

# %%
# Tokenizing text
tokenizer = Tokenizer()
tokenizer.fit_on_texts(X)
X_seq = tokenizer.texts_to_sequences(X)
X= tokenizer.word_index

# %%
X
# Out:
# {'ya': 1,
#  'a': 2,
#  'le': 3,
#  'ka': 4,
#  'go': 5,
#  'e': 6,
#  'na': 7,
#  'u': 8,
#  'die': 9,
#  'wa': 10,
#  'the': 11,
#  'ba': 12,
#  'o': 13,
#  'ho': 14,
#  'ku': 15,
#  'of': 16,
#  'nga': 17,
#  'ke': 18,
#  'in': 19,
#  'di': 20,
#  'sa': 21,
#  'ha': 22,
#  'tsa': 23,
#  'se': 24,
#  'van': 25,
#  'vha': 26,
#  'mo': 27,
#  'to': 28,
#  'hi': 29,
#  'and': 30,
#  'la': 31,
#  'is': 32,
#  'en': 33,
#  'tse': 34,
#  'n': 35,
#  'i': 36,
#  'kha': 37,
#  'ga': 38,
#  'tša': 39,
#  'eka': 40,
#  'gore': 41,
#  'yo': 42,
#  'afrika': 43,
#  'tla': 44,
#  'kanye': 45,
#  'va': 46,
#  'te': 47,
#  'xa': 48,
#  'ta': 49,
#  're': 50,
#  'ukuba': 51,
#  'wat': 52,
#  'bona': 53,
#  'noma': 54,
#  'word': 55,
#  'as': 56,
#  'mme': 57,
#  'be': 58,
#  'kana': 59,
#  'om': 60,
#  'ye': 61,
#  'or': 62,
#  'hore': 63,
#  'dza': 64,
#  'by': 65,
#  'tshi': 66,
#  'nie': 67,
#  'fa': 68,
#  'for': 69,
#  'swi': 70,
#  'uma': 71,
#  'ri': 72,
#  'uri': 73,
#  'bo': 74,
#  'molao': 75,
#  'zwa': 76,
#  'kapa': 77,
#  'kumbe': 78,
#  'kutsi': 79,
#  'ge': 80,
#  'vir': 81,
#  'okanye': 82,
#  'goba': 83,
#  'yi': 84,
#  'that': 85,
#  'kwa': 86,
#  'loko': 87,
#  'het': 88,
#  'swa': 89,
#  'no': 90,
#  'b': 91,
#  'ukuthi': 92,
#  'tše': 93,
#  'zwi': 94,
#  'hu': 95,
#  'leswaku': 96,
#  'batho': 97,
#  'wo': 98,
#  'nobe': 99,
#  'motho': 100,
#  'leyi': 101,
#  'pele': 102,
#  'yona': 103,
#  'op': 104,
#  'yeo': 105,
#  'leswi': 106,
#  'r': 107,
#  'on': 108,
#  'kufanele': 109,
#  'namkha': 110,
#  'met': 111,
#  'aan': 112,
#  'ra': 113,
#  'wana': 114,
#  'ni': 115,
#  'tea': 116,
#  'moet': 117,
#  'with': 118,
#  'borwa': 119,
#  'nngwe': 120,
#  'sal': 121,
#  'kumele': 122,
#  'kan': 123,
#  'dit': 124,
#  'tsha': 125,
#  'khona': 126,
#  'ne': 127,
#  'ndi': 128,
#  'we': 129,
#  'nna': 130,
#  'tshwanetse': 131,
#  'dira': 132,
#  'bya': 133,
#  'kunye': 134,
#  'nako': 135,
#  'ngaphandle': 136,
#  'act': 137,
#  'wu': 138,
#  'this': 139,
#  'wena': 140,
#  'fanele': 141,
#  'kgotsa': 142,
#  'futhi': 143,
#  'dat': 144,
#  'lowu': 145,
#  'kufuneka': 146,
#  'karolo': 147,
#  'lapho': 148,
#  'vho': 149,
#  'deur': 150,
#  'an': 151,
#  'umsebenzi': 152,
#  'arali': 153,
#  'dzi': 154,
#  'moo': 155,
#  'any': 156,
#  'teng': 157,
#  'bja': 158,
#  'begodu': 159,
#  'jwa': 160,
#  'fela': 161,
#  'khou': 162,
#  'abantu': 163,
#  'futsi': 164,
#  'swanetše': 165,
#  'ntle': 166,
#  'eo': 167,
#  'ukuze': 168,
#  'kona': 169,
#  'c': 170,
#  'ita': 171,
#  'ḓo': 172,
#  'musi': 173,
#  'umuntu': 174,
#  'xi': 175,
#  'si': 176,
#  'ons': 177,
#  'are': 178,
#  'lo': 179,
#  'tšeo': 180,
#  'umthetho': 181,
#  's': 182,
#  'jy': 183,
#  'imali': 184,
#  'was': 185,
#  'setšhaba': 186,
#  'yena': 187,
#  'at': 188,
#  'lava': 189,
#  'mulayo': 190,
#  'ngendlela': 191,
#  'mongwe': 192,
#  'may': 193,
#  'gago': 194,
#  'not': 195,
#  'ao': 196,
#  'nawu': 197,
#  'maemo': 198,
#  'vhathu': 199,
#  'ndzi': 200,
#  'rona': 201,
#  'ena': 202,
#  'seo': 203,
#  'hierdie': 204,
#  'mokgwa': 205,
#  'jwalo': 206,
#  'it': 207,
#  'kakhulu': 208,
#  'bjalo': 209,
#  'muthu': 210,
#  'mabapi': 211,
#  'leng': 212,
#  'bese': 213,
#  'nkarhi': 214,
#  'khumbelo': 215,
#  'tshipembe': 216,
#  'such': 217,
#  'bao': 218,
#  'morago': 219,
#  'nje': 220,
#  'section': 221,
#  'etsa': 222,
#  'tsela': 223,
#  'lexi': 224,
#  'kahle': 225,
#  'has': 226,
#  'munhu': 227,
#  'bakeng': 228,
#  'metsi': 229,
#  'endla': 230,
#  'tswa': 231,
#  'mali': 232,
#  'zwo': 233,
#  'hulle': 234,
#  'which': 235,
#  'ine': 236,
#  'nang': 237,
#  'jou': 238,
#  'from': 239,
#  'ḽa': 240,
#  'lokhu': 241,
#  'loyi': 242,
#  'gona': 243,
#  'indlela': 244,
#  'vanhu': 245,
#  'lona': 246,
#  'gape': 247,
#  'south': 248,
#  'leo': 249,
#  'ngayo': 250,
#  'vona': 251,
#  'fana': 252,
#  'will': 253,
#  'nahone': 254,
#  'laha': 255,
#  'ngabe': 256,
#  'jaaka': 257,
#  'efe': 258,
#  'taolo': 259,
#  'ndlela': 260,
#  'kwaye': 261,
#  'isicelo': 262,
#  'gomme': 263,
#  'must': 264,
#  'kopo': 265,
#  'leri': 266,
#  'dingwe': 267,
#  'lokela': 268,
#  'tot': 269,
#  'mayelana': 270,
#  'kodwa': 271,
#  'gagwe': 272,
#  'lowo': 273,
#  'ona': 274,
#  'tlase': 275,
#  'thoma': 276,
#  'loku': 277,
#  'dintlha': 278,
#  'ook': 279,
#  'kube': 280,
#  'so': 281,
#  'd': 282,
#  'leti': 283,
#  'oor': 284,
#  'national': 285,
#  'ngaphambi': 286,
#  'lushaka': 287,
#  'shall': 288,
#  'setjhaba': 289,
#  'tshumelo': 290,
#  'muvhuso': 291,
#  'bohlokwa': 292,
#  'kgwebo': 293,
#  'mthetho': 294,
#  'ti': 295,
#  'xiyenge': 296,
#  'ile': 297,
#  'lefapha': 298,
#  'isikhathi': 299,
#  'feta': 300,
#  'ane': 301,
#  'bana': 302,
#  'bokgoni': 303,
#  'have': 304,
#  'tsamaiso': 305,
#  'moka': 306,
#  'mong': 307,
#  'ngwana': 308,
#  'minister': 309,
#  'lwa': 310,
#  'vhe': 311,
#  'bonyana': 312,
#  'emva': 313,
#  'tsona': 314,
#  'hao': 315,
#  'terms': 316,
#  'vhu': 317,
#  'ofe': 318,
#  'tshifhinga': 319,
#  'mfumo': 320,
#  'komiti': 321,
#  'lekgotla': 322,
#  'kuphela': 323,
#  'daar': 324,
#  'ofisi': 325,
#  'mabaka': 326,
#  'zwine': 327,
#  'if': 328,
#  'mmuso': 329,
#  'sy': 330,
#  'person': 331,
#  'mosebetsi': 332,
#  'godimo': 333,
#  'enige': 334,
#  'indien': 335,
#  'thuto': 336,
#  'kgolo': 337,
#  'thusa': 338,
#  'dzo': 339,
#  'phakathi': 340,
#  'naswona': 341,
#  'other': 342,
#  'gems': 343,
#  'njalo': 344,
#  'fanela': 345,
#  'aforika': 346,
#  'leyo': 347,
#  'umntu': 348,
#  'ntirho': 349,
#  'ama': 350,
#  'all': 351,
#  'lebaka': 352,
#  'latela': 353,
#  'imisebenzi': 354,
#  'mafhungo': 355,
#  'kute': 356,
#  'hone': 357,
#  'ngwaga': 358,
#  'puo': 359,
#  'suid': 360,
#  'xikombelo': 361,
#  'been': 362,
#  'court': 363,
#  'tiko': 364,
#  'tseo': 365,
#  'sicelo': 366,
#  'phambili': 367,
#  'ukusebenza': 368,
#  'nakong': 369,
#  'swo': 370,
#  'african': 371,
#  'hae': 372,
#  'tsena': 373,
#  'maleba': 374,
#  'lenaneo': 375,
#  'naha': 376,
#  'kuba': 377,
#  'government': 378,
#  'ukwenza': 379,
#  'ditirelo': 380,
#  'jalo': 381,
#  'ander': 382,
#  'yakho': 383,
#  'ntse': 384,
#  'tshedimosetso': 385,
#  'seng': 386,
#  'hune': 387,
#  'lapha': 388,
#  'ntlha': 389,
#  'lego': 390,
#  'africa': 391,
#  'feela': 392,
#  'khothe': 393,
#  'kufuze': 394,
#  'fhasi': 395,
#  'kuma': 396,
#  'wona': 397,
#  'yini': 398,
#  'nyika': 399,
#  'into': 400,
#  'neng': 401,
#  'bantfu': 402,
#  'ngo': 403,
#  'ngaphasi': 404,
#  'development': 405,
#  'tshebetso': 406,
#  'bva': 407,
#  'tou': 408,
#  'gongwe': 409,
#  'kokuba': 410,
#  'tiro': 411,
#  'shuma': 412,
#  'sakho': 413,
#  'gebruik': 414,
#  'jaar': 415,
#  'bosetšhaba': 416,
#  'izinto': 417,
#  'do': 418,
#  'mushumo': 419,
#  'tona': 420,
#  'apho': 421,
#  'nofana': 422,
#  'departement': 423,
#  'motheo': 424,
#  'public': 425,
#  'meer': 426,
#  'nkoka': 427,
#  'kobana': 428,
#  'zonke': 429,
#  'xo': 430,
#  'byi': 431,
#  'bile': 432,
#  'abasebenzi': 433,
#  'timhaka': 434,
#  'vhane': 435,
#  'muhasho': 436,
#  'umuntfu': 437,
#  'its': 438,
#  'department': 439,
#  'maloko': 440,
#  'songo': 441,
#  'ro': 442,
#  'he': 443,
#  'bophelo': 444,
#  'under': 445,
#  'wees': 446,
#  'khulu': 447,
#  'thendelo': 448,
#  'naga': 449,
#  'soos': 450,
#  'ngesikhathi': 451,
#  'who': 452,
#  'huvo': 453,
#  'uit': 454,
#  'mekgwa': 455,
#  'subsection': 456,
#  'mfanelo': 457,
#  'maak': 458,
#  'wakho': 459,
#  'per': 460,
#  'dzonga': 461,
#  'ngemuva': 462,
#  'baithuti': 463,
#  'tirha': 464,
#  'mina': 465,
#  'merero': 466,
#  'nanyana': 467,
#  'hina': 468,
#  'mintirho': 469,
#  'tlhokomelo': 470,
#  'service': 471,
#  'kgopelo': 472,
#  'muṅwe': 473,
#  'lama': 474,
#  'dzine': 475,
#  'xiyimo': 476,
#  'faneleke': 477,
#  'tirhisa': 478,
#  'hiv': 479,
#  'sena': 480,
#  'doen': 481,
#  'ngaphansi': 482,
#  'jo': 483,
#  'ithuta': 484,
#  'khethekanyo': 485,
#  'nakube': 486,
#  'indawo': 487,
#  'karhi': 488,
#  'murahu': 489,
#  'isibawo': 490,
#  'nasionale': 491,
#  'ditaba': 492,
#  'ulwazi': 493,
#  'yakhe': 494,
#  'teaho': 495,
#  'phanḓa': 496,
#  'thuso': 497,
#  'kgona': 498,
#  'kanti': 499,
#  'thata': 500,
#  'itela': 501,
#  'molaotheo': 502,
#  'abe': 503,
#  'ngalo': 504,
#  'raad': 505,
#  'nge': 506,
#  'sungula': 507,
#  'nangabe': 508,
#  'financial': 509,
#  'rixaka': 510,
#  'tshedimošo': 511,
#  'vhona': 512,
#  'ten': 513,
#  'mohlala': 514,
#  'amandla': 515,
#  'kuhle': 516,
#  'lefelo': 517,
#  'haholo': 518,
#  'rena': 519,
#  'mmušo': 520,
#  'time': 521,
#  'tirelo': 522,
#  'hambana': 523,
#  'empa': 524,
#  'amanzi': 525,
#  'mang': 526,
#  'taba': 527,
#  'state': 528,
#  'lokho': 529,
#  'landza': 530,
#  'sikhatsi': 531,
#  'mense': 532,
#  'itwa': 533,
#  'mona': 534,
#  'gare': 535,
#  'ko': 536,
#  'ek': 537,
#  'their': 538,
#  'kudu': 539,
#  'sebaka': 540,
#  'mhaka': 541,
#  'tšwa': 542,
#  'oku': 543,
#  'kuya': 544,
#  'kgone': 545,
#  'njengoba': 546,
#  'hona': 547,
#  'sona': 548,
#  'ngenxa': 549,
#  'year': 550,
#  'mmoho': 551,
#  'kantsi': 552,
#  'endzhaku': 553,
#  'lebyi': 554,
#  'aansoek': 555,
#  'services': 556,
#  'ze': 557,
#  'dijo': 558,
#  'ehansi': 559,
#  'ḽi': 560,
#  'botlhokwa': 561,
#  'batla': 562,
#  'jwale': 563,
#  'hape': 564,
#  'madi': 565,
#  'water': 566,
#  'eli': 567,
#  'alle': 568,
#  'siku': 569,
#  'jikelele': 570,
#  'werk': 571,
#  'shumisa': 572,
#  'maikarabelo': 573,
#  'dirwa': 574,
#  'mmogo': 575,
#  'mbadelo': 576,
#  'palamente': 577,
#  'yabo': 578,
#  'ḓi': 579,
#  'ditjhelete': 580,
#  'ibe': 581,
#  'lefatshe': 582,
#  'tshitshavha': 583,
#  'tshwanetseng': 584,
#  'ditiro': 585,
#  'yavho': 586,
#  'ntshetsopele': 587,
#  'netefatsa': 588,
#  'dipuo': 589,
#  'nago': 590,
#  'phantsi': 591,
#  'gammogo': 592,
#  'ngemva': 593,
#  'ii': 594,
#  'our': 595,
#  'fhedzi': 596,
#  'mahungu': 597,
#  'palo': 598,
#  'tokelo': 599,
#  'provinsiale': 600,
#  'amba': 601,
#  'mošomo': 602,
#  'emahlweni': 603,
#  'sars': 604,
#  'puso': 605,
#  'maar': 606,
#  'kambe': 607,
#  'tala': 608,
#  'een': 609,
#  'billion': 610,
#  'wonke': 611,
#  'swona': 612,
#  'wet': 613,
#  'boleng': 614,
#  'letsatsi': 615,
#  'omunye': 616,
#  'kodvwa': 617,
#  'sengwe': 618,
#  'tloga': 619,
#  'shumiswa': 620,
#  'hy': 621,
#  'ngoba': 622,
#  'maatla': 623,
#  'ukuya': 624,
#  'were': 625,
#  'melao': 626,
#  'provincial': 627,
#  'elke': 628,
#  'within': 629,
#  'milawu': 630,
#  'more': 631,
#  'handle': 632,
#  'ndeme': 633,
#  'lakho': 634,
#  'šoma': 635,
#  'kwe': 636,
#  'ikonomi': 637,
#  'ngokuthi': 638,
#  'ditšhelete': 639,
#  'also': 640,
#  'muthelo': 641,
#  'ding': 642,
#  'kopano': 643,
#  'dirisa': 644,
#  'ḓa': 645,
#  'order': 646,
#  'bang': 647,
#  'tikologo': 648,
#  'iyi': 649,
#  'tumelelo': 650,
#  'kodwana': 651,
#  'aids': 652,
#  'fomo': 653,
#  'his': 654,
#  'hloka': 655,
#  'vatirhi': 656,
#  'bonke': 657,
#  'bobedi': 658,
#  'kuyo': 659,
#  'wanneer': 660,
#  'waar': 661,
#  'mishumo': 662,
#  'polelo': 663,
#  'foromo': 664,
#  'matimba': 665,
#  'tšona': 666,
#  'matla': 667,
#  'unwana': 668,
#  'nayo': 669,
#  'kusukela': 670,
#  'woke': 671,
#  'ditokelo': 672,
#  'basebetsi': 673,
#  'persoon': 674,
#  'wes': 675,
#  'nyaka': 676,
#  'tsohle': 677,
#  'bjo': 678,
#  'tanihi': 679,
#  'nne': 680,
#  'tindlela': 681,
#  'leloko': 682,
#  'phambi': 683,
#  'bangwe': 684,
#  'bolaodi': 685,
#  'endaweni': 686,
#  'fumana': 687,
#  'ukuqinisekisa': 688,
#  'tseba': 689,
#  'tsho': 690,
#  'melawana': 691,
#  'njani': 692,
#  'f': 693,
#  'kgoro': 694,
#  'm': 695,
#  'one': 696,
#  'swilaveko': 697,
#  'yonke': 698,
#  'amalungelo': 699,
#  'commission': 700,
#  'emsebenzini': 701,
#  'mathata': 702,
#  'lena': 703,
#  'authority': 704,
#  'maikutlo': 705,
#  'management': 706,
#  'tlhela': 707,
#  'kuwo': 708,
#  'dié': 709,
#  'lawa': 710,
#  'amogela': 711,
#  'gaan': 712,
#  'ube': 713,
#  'kule': 714,
#  'vhashumi': 715,
#  'tjhelete': 716,
#  'pholisi': 717,
#  'programme': 718,
#  'nḓila': 719,
#  'loyo': 720,
#  'than': 721,
#  'incwadi': 722,
#  'maitele': 723,
#  'letona': 724,
#  'komthetho': 725,
#  'pfanelo': 726,
#  'tsotlhe': 727,
#  'mbekanyamushumo': 728,
#  'botlalo': 729,
#  'these': 730,
#  'land': 731,
#  'mokgatlo': 732,
#  'sebedisa': 733,
#  'labo': 734,
#  'eningizimu': 735,
#  'farologaneng': 736,
#  'endliwa': 737,
#  'tšhelete': 738,
#  'isibonelo': 739,
#  'al': 740,
#  'ḓuvha': 741,
#  'report': 742,
#  'lengwe': 743,
#  'sigaba': 744,
#  'nnete': 745,
#  'inligting': 746,
#  'boitekanelo': 747,
#  'kwama': 748,
#  'g': 749,
#  'committee': 750,
#  'magareng': 751,
#  'karolwana': 752,
#  'naye': 753,
#  'wakhe': 754,
#  'kukhona': 755,
#  'nomoro': 756,
#  'vula': 757,
#  'swana': 758,
#  'kulo': 759,
#  'tshwanelo': 760,
#  'general': 761,
#  'khansele': 762,
#  'somthetho': 763,
#  'kuye': 764,
#  'pedi': 765,
#  'ditshebeletso': 766,
#  'isa': 767,
#  'cent': 768,
#  'dife': 769,
#  'mešomo': 770,
#  'mananeo': 771,
#  'ditho': 772,
#  'hwetša': 773,
#  'setso': 774,
#  'company': 775,
#  'selegae': 776,
#  'fhethu': 777,
#  'masipala': 778,
#  'regering': 779,
#  'lokha': 780,
#  'kgwedi': 781,
#  'information': 782,
#  'tšea': 783,
#  'fhela': 784,
#  'godu': 785,
#  'bontsha': 786,
#  'kakaretso': 787,
#  'itseng': 788,
#  'cape': 789,
#  'ntsena': 790,
#  'lenyalo': 791,
#  'deel': 792,
#  'baka': 793,
#  'taelo': 794,
#  'kutani': 795,
#  'bone': 796,
#  'njengobe': 797,
#  'sego': 798,
#  'lefelong': 799,
#  'moralo': 800,
#  'uya': 801,
#  'yoo': 802,
#  'loo': 803,
#  'sebetsa': 804,
#  'setho': 805,
#  'kazwelonke': 806,
#  'tani': 807,
#  'umtsetfo': 808,
#  'ezi': 809,
#  'nayikuthi': 810,
#  'bohle': 811,
#  'fapaneng': 812,
#  'mesebetsi': 813,
#  'bolela': 814,
#  'selemo': 815,
#  'after': 816,
#  'baie': 817,
#  'swirho': 818,
#  'council': 819,
#  'shango': 820,
#  'h': 821,
#  'phela': 822,
#  'mangwe': 823,
#  'kotsi': 824,
#  'ngokomthetho': 825,
#  'milayo': 826,
#  'afurika': 827,
#  'maemong': 828,
#  'fihla': 829,
#  'zabo': 830,
#  'vumbiwa': 831,
#  'cbnrm': 832,
#  'there': 833,
#  'wil': 834,
#  'sakhe': 835,
#  'kwekutsi': 836,
#  'muofisiri': 837,
#  'lembe': 838,
#  'morero': 839,
#  'board': 840,
#  'law': 841,
#  'ema': 842,
#  'karolong': 843,
#  'imvume': 844,
#  'artikel': 845,
#  'malugana': 846,
#  'date': 847,
#  'tiyisisa': 848,
#  'period': 849,
#  'made': 850,
#  'kunjalo': 851,
#  'umkhandlu': 852,
#  'abo': 853,
#  'umntwana': 854,
#  'but': 855,
#  'boikarabelo': 856,
#  'maphelo': 857,
#  'vaaki': 858,
#  'malebana': 859,
#  'akukho': 860,
#  'ririmi': 861,
#  'oko': 862,
#  'my': 863,
#  'ngawo': 864,
#  'mutirhi': 865,
#  'leano': 866,
#  'openbare': 867,
#  'tshebediso': 868,
#  'woo': 869,
#  'kuthi': 870,
#  'molato': 871,
#  'kry': 872,
#  'sekolo': 873,
#  'million': 874,
#  'binne': 875,
#  'dzhia': 876,
#  'dovha': 877,
#  'byo': 878,
#  'nnḓa': 879,
#  'respect': 880,
#  'bego': 881,
#  'saathu': 882,
#  'tirhisiwa': 883,
#  'tshelede': 884,
#  'katsa': 885,
#  'should': 886,
#  'her': 887,
#  'wua': 888,
#  'setifikeiti': 889,
#  'ja': 890,
#  'kwabo': 891,
#  'ingevolge': 892,
#  'potchefstroom': 893,
#  'kufaka': 894,
#  'nka': 895,
#  'basadi': 896,
#  'miv': 897,
#  'kaap': 898,
#  'kone': 899,
#  'fe': 900,
#  'molawana': 901,
#  'mutakalo': 902,
#  'vhone': 903,
#  'dula': 904,
#  'swinene': 905,
#  'hlangana': 906,
#  'members': 907,
#  'nuwe': 908,
#  'tswang': 909,
#  'stel': 910,
#  'tharo': 911,
#  'health': 912,
#  'tonkhe': 913,
#  'dilo': 914,
#  'masheleni': 915,
#  'bogolo': 916,
#  'uhlelo': 917,
#  'mafelo': 918,
#  'sephetho': 919,
#  'lu': 920,
#  'kota': 921,
#  'vhukati': 922,
#  'vhana': 923,
#  'eng': 924,
#  'kwakunye': 925,
#  'they': 926,
#  'tee': 927,
#  'misava': 928,
#  'umnyango': 929,
#  'mi': 930,
#  'masiku': 931,
#  'moya': 932,
#  'bothata': 933,
#  'kukho': 934,
#  'fetileng': 935,
#  'yomthetho': 936,
#  'zwe': 937,
#  'teen': 938,
#  'suka': 939,
#  'hul': 940,
#  'betaal': 941,
#  'semolao': 942,
#  'ngonyaka': 943,
#  'babe': 944,
#  'child': 945,
#  'ngaka': 946,
#  'laola': 947,
#  'ndhawu': 948,
#  'people': 949,
#  'abantwana': 950,
#  'system': 951,
#  'mekgatlo': 952,
#  'henhla': 953,
#  'nokuthi': 954,
#  'tshebeletso': 955,
#  'yaye': 956,
#  'sehlopha': 957,
#  'ngopfu': 958,
#  'yinwana': 959,
#  'eba': 960,
#  'ndzawulo': 961,
#  'timali': 962,
#  'hara': 963,
#  'amathuba': 964,
#  'ilungelo': 965,
#  'saps': 966,
#  'enye': 967,
#  'daardie': 968,
#  'fao': 969,
#  'nabo': 970,
#  'mpfumelelo': 971,
#  'romela': 972,
#  'ngokuya': 973,
#  'make': 974,
#  'wethu': 975,
#  'isigaba': 976,
#  'ofisini': 977,
#  'hezwi': 978,
#  'latelang': 979,
#  'nokuba': 980,
#  'zwithu': 981,
#  'leso': 982,
#  'ndivho': 983,
#  'before': 984,
#  'monna': 985,
#  'out': 986,
#  'pakeng': 987,
#  'mulayotewa': 988,
#  'bakhe': 989,
#  'haeba': 990,
#  'haar': 991,
#  'sebakeng': 992,
#  'dithoto': 993,
#  'diriša': 994,
#  'ma': 995,
#  'provide': 996,
#  'motlakase': 997,
#  'isaziso': 998,
#  'president': 999,
#  'mag': 1000,
#  ...}

# %%
# Pad sequences
max_len = max([len(seq) for seq in X_seq])
X_pad = pad_sequences(X_seq, maxlen=max_len, padding='post')

# %%
# label_Encode
label_encoder = LabelEncoder()
y_enc = label_encoder.fit_transform(y)

# %%
import numpy as np
from sklearn.model_selection import train_test_split

# Sample data
X_pad = np.random.rand(1000, 100)  # 1000 samples, 100 features each
y_enc = np.random.randint(0, 10, size=(1000,))  # 1000 samples, 10 possible classes

# Check consistency
print("X_pad shape:", X_pad.shape)
print("y_enc length:", len(y_enc))

# Split data
X_train, X_test, y_train, y_test = train_test_split(X_pad, y_enc, test_size=0.2, random_state=42)
# Out:
# X_pad shape: (1000, 100)
# y_enc length: 1000

# %%
from tensorflow.keras.layers import Embedding, LSTM, Dense, Bidirectional, BatchNormalization, Dropout
from tensorflow.keras.models import Sequential

# Determine the vocabulary size and number of classes
vocab_size = len(tokenizer.word_index) + 1
num_classes = len(label_tokenizer.word_index)

# Define the model
model = Sequential()
model.add(Embedding(input_dim=vocab_size, output_dim=128, input_length=maxlen))
model.add(Bidirectional(LSTM(64, return_sequences=True)))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Bidirectional(LSTM(64)))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))

# Compile the model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(X_train, y_train, epochs=50, batch_size=40, validation_split=0.2)
# Out:
# Epoch 1/50
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# Cell In[86], line 23
#      20 model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
#      22 # Train the model
# ---> 23 history = model.fit(X_train, y_train, epochs=50, batch_size=40, validation_split=0.2)
#
# File /opt/anaconda3/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File /opt/anaconda3/lib/python3.11/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# InvalidArgumentError: Graph execution error:
#
# Detected at node ArgMax defined at (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#
#   File "<frozen runpy>", line 88, in _run_code
#
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel_launcher.py", line 17, in <module>
#
#   File "/opt/anaconda3/lib/python3.11/site-packages/traitlets/config/application.py", line 992, in launch_instance
#
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/kernelapp.py", line 701, in start
#
#   File "/opt/anaconda3/lib/python3.11/site-packages/tornado/platform/asyncio.py", line 195, in start
#
#   File "/opt/anaconda3/lib/python3.11/asyncio/base_events.py", line 607, in run_forever
#
#   File "/opt/anaconda3/lib/python3.11/asyncio/base_events.py", line 1922, in _run_once
#
#   File "/opt/anaconda3/lib/python3.11/asyncio/events.py", line 80, in _run
#
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 534, in dispatch_queue
#
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 523, in process_one
#
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 429, in dispatch_shell
#
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 767, in execute_request
#
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 429, in do_execute
#
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#
#   File "/opt/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3051, in run_cell
#
#   File "/opt/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3106, in _run_cell
#
#   File "/opt/anaconda3/lib/python3.11/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#
#   File "/opt/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3311, in run_cell_async
#
#   File "/opt/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3493, in run_ast_nodes
#
#   File "/opt/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#
#   File "/var/folders/dt/lksn0l5j6md0rhyypnfyzwbr0000gn/T/ipykernel_10844/772721027.py", line 23, in <module>
#
#   File "/opt/anaconda3/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py", line 117, in error_handler
#
#   File "/opt/anaconda3/lib/python3.11/site-packages/keras/src/backend/tensorflow/trainer.py", line 318, in fit
#
#   File "/opt/anaconda3/lib/python3.11/site-packages/keras/src/backend/tensorflow/trainer.py", line 121, in one_step_on_iterator
#
#   File "/opt/anaconda3/lib/python3.11/site-packages/keras/src/backend/tensorflow/trainer.py", line 108, in one_step_on_data
#
#   File "/opt/anaconda3/lib/python3.11/site-packages/keras/src/backend/tensorflow/trainer.py", line 77, in train_step
#
#   File "/opt/anaconda3/lib/python3.11/site-packages/keras/src/trainers/trainer.py", line 444, in compute_metrics
#
#   File "/opt/anaconda3/lib/python3.11/site-packages/keras/src/trainers/compile_utils.py", line 330, in update_state
#
#   File "/opt/anaconda3/lib/python3.11/site-packages/keras/src/trainers/compile_utils.py", line 17, in update_state
#
#   File "/opt/anaconda3/lib/python3.11/site-packages/keras/src/metrics/reduction_metrics.py", line 204, in update_state
#
#   File "/opt/anaconda3/lib/python3.11/site-packages/keras/src/metrics/accuracy_metrics.py", line 240, in sparse_categorical_accuracy
#
#   File "/opt/anaconda3/lib/python3.11/site-packages/keras/src/ops/numpy.py", line 869, in argmax
#
#   File "/opt/anaconda3/lib/python3.11/site-packages/keras/src/backend/tensorflow/numpy.py", line 772, in argmax
#
# Reduction axis -1 is empty in shape [40,0]
# 	 [[{{node ArgMax}}]] [Op:__inference_one_step_on_iterator_774614]

# %%
from tensorflow.keras.layers import Embedding, LSTM, Dense, Bidirectional, BatchNormalization, Dropout
from tensorflow.keras.models import Sequential

# Determine the vocabulary size and number of classes
vocab_size = len(tokenizer.word_index) + 1
num_classes = len(label_tokenizer.word_index)

# Define the model
model = Sequential()
model.add(Embedding(input_dim=vocab_size, output_dim=128, input_length=maxlen))
model.add(Bidirectional(LSTM(64, return_sequences=True)))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Bidirectional(LSTM(64)))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))

# Compile the model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(X_train, y_train, epochs=50, batch_size=40, validation_split=0.2)
# Out:
# Epoch 1/50
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# Cell In[85], line 23
#      20 model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
#      22 # Train the model
# ---> 23 history = model.fit(X_train, y_train, epochs=50, batch_size=40, validation_split=0.2)
#
# File /opt/anaconda3/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File /opt/anaconda3/lib/python3.11/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# InvalidArgumentError: Graph execution error:
#
# Detected at node compile_loss/sparse_categorical_crossentropy/SparseSoftmaxCrossEntropyWithLogits/SparseSoftmaxCrossEntropyWithLogits defined at (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#
#   File "<frozen runpy>", line 88, in _run_code
#
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel_launcher.py", line 17, in <module>
#
#   File "/opt/anaconda3/lib/python3.11/site-packages/traitlets/config/application.py", line 992, in launch_instance
#
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/kernelapp.py", line 701, in start
#
#   File "/opt/anaconda3/lib/python3.11/site-packages/tornado/platform/asyncio.py", line 195, in start
#
#   File "/opt/anaconda3/lib/python3.11/asyncio/base_events.py", line 607, in run_forever
#
#   File "/opt/anaconda3/lib/python3.11/asyncio/base_events.py", line 1922, in _run_once
#
#   File "/opt/anaconda3/lib/python3.11/asyncio/events.py", line 80, in _run
#
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 534, in dispatch_queue
#
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 523, in process_one
#
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 429, in dispatch_shell
#
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 767, in execute_request
#
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 429, in do_execute
#
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#
#   File "/opt/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3051, in run_cell
#
#   File "/opt/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3106, in _run_cell
#
#   File "/opt/anaconda3/lib/python3.11/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#
#   File "/opt/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3311, in run_cell_async
#
#   File "/opt/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3493, in run_ast_nodes
#
#   File "/opt/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#
#   File "/var/folders/dt/lksn0l5j6md0rhyypnfyzwbr0000gn/T/ipykernel_10844/3044964441.py", line 23, in <module>
#
#   File "/opt/anaconda3/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py", line 117, in error_handler
#
#   File "/opt/anaconda3/lib/python3.11/site-packages/keras/src/backend/tensorflow/trainer.py", line 318, in fit
#
#   File "/opt/anaconda3/lib/python3.11/site-packages/keras/src/backend/tensorflow/trainer.py", line 121, in one_step_on_iterator
#
#   File "/opt/anaconda3/lib/python3.11/site-packages/keras/src/backend/tensorflow/trainer.py", line 108, in one_step_on_data
#
#   File "/opt/anaconda3/lib/python3.11/site-packages/keras/src/backend/tensorflow/trainer.py", line 54, in train_step
#
#   File "/opt/anaconda3/lib/python3.11/site-packages/keras/src/trainers/trainer.py", line 357, in _compute_loss
#
#   File "/opt/anaconda3/lib/python3.11/site-packages/keras/src/trainers/trainer.py", line 325, in compute_loss
#
#   File "/opt/anaconda3/lib/python3.11/site-packages/keras/src/trainers/compile_utils.py", line 609, in __call__
#
#   File "/opt/anaconda3/lib/python3.11/site-packages/keras/src/trainers/compile_utils.py", line 645, in call
#
#   File "/opt/anaconda3/lib/python3.11/site-packages/keras/src/losses/loss.py", line 43, in __call__
#
#   File "/opt/anaconda3/lib/python3.11/site-packages/keras/src/losses/losses.py", line 27, in call
#
#   File "/opt/anaconda3/lib/python3.11/site-packages/keras/src/losses/losses.py", line 1853, in sparse_categorical_crossentropy
#
#   File "/opt/anaconda3/lib/python3.11/site-packages/keras/src/ops/nn.py", line 1567, in sparse_categorical_crossentropy
#
#   File "/opt/anaconda3/lib/python3.11/site-packages/keras/src/backend/tensorflow/nn.py", line 645, in sparse_categorical_crossentropy
#
# Must have at least one class, but got logits shape [40,0]
# 	 [[{{node compile_loss/sparse_categorical_crossentropy/SparseSoftmaxCrossEntropyWithLogits/SparseSoftmaxCrossEntropyWithLogits}}]] [Op:__inference_one_step_on_iterator_766851]

# %%
from tensorflow.keras.layers import Embedding, LSTM, Dense, Bidirectional, BatchNormalization, Dropout
from tensorflow.keras.models import Sequential

# Define model
model = Sequential()
model.add(Embedding(input_dim=len(X) + 1, output_dim=128, input_length=maxlen))
model.add(Bidirectional(LSTM(64, return_sequences=True)))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Bidirectional(LSTM(64)))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(len(label_tokenizer.word_index), activation='softmax'))

# Compile model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(X_train, y_train, epochs=50, batch_size=40, validation_split=0.2)
# Out:
# Epoch 1/50
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# Cell In[71], line 19
#      16 model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
#      18 # Train the model
# ---> 19 history = model.fit(X_train, y_train, epochs=50, batch_size=40, validation_split=0.2)
#
# File /opt/anaconda3/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File /opt/anaconda3/lib/python3.11/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# InvalidArgumentError: Graph execution error:
#
# Detected at node ArgMax defined at (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#
#   File "<frozen runpy>", line 88, in _run_code
#
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel_launcher.py", line 17, in <module>
#
#   File "/opt/anaconda3/lib/python3.11/site-packages/traitlets/config/application.py", line 992, in launch_instance
#
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/kernelapp.py", line 701, in start
#
#   File "/opt/anaconda3/lib/python3.11/site-packages/tornado/platform/asyncio.py", line 195, in start
#
#   File "/opt/anaconda3/lib/python3.11/asyncio/base_events.py", line 607, in run_forever
#
#   File "/opt/anaconda3/lib/python3.11/asyncio/base_events.py", line 1922, in _run_once
#
#   File "/opt/anaconda3/lib/python3.11/asyncio/events.py", line 80, in _run
#
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 534, in dispatch_queue
#
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 523, in process_one
#
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 429, in dispatch_shell
#
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 767, in execute_request
#
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 429, in do_execute
#
#   File "/opt/anaconda3/lib/python3.11/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#
#   File "/opt/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3051, in run_cell
#
#   File "/opt/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3106, in _run_cell
#
#   File "/opt/anaconda3/lib/python3.11/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#
#   File "/opt/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3311, in run_cell_async
#
#   File "/opt/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3493, in run_ast_nodes
#
#   File "/opt/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#
#   File "/var/folders/dt/lksn0l5j6md0rhyypnfyzwbr0000gn/T/ipykernel_10844/1540384463.py", line 19, in <module>
#
#   File "/opt/anaconda3/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py", line 117, in error_handler
#
#   File "/opt/anaconda3/lib/python3.11/site-packages/keras/src/backend/tensorflow/trainer.py", line 318, in fit
#
#   File "/opt/anaconda3/lib/python3.11/site-packages/keras/src/backend/tensorflow/trainer.py", line 121, in one_step_on_iterator
#
#   File "/opt/anaconda3/lib/python3.11/site-packages/keras/src/backend/tensorflow/trainer.py", line 108, in one_step_on_data
#
#   File "/opt/anaconda3/lib/python3.11/site-packages/keras/src/backend/tensorflow/trainer.py", line 77, in train_step
#
#   File "/opt/anaconda3/lib/python3.11/site-packages/keras/src/trainers/trainer.py", line 444, in compute_metrics
#
#   File "/opt/anaconda3/lib/python3.11/site-packages/keras/src/trainers/compile_utils.py", line 330, in update_state
#
#   File "/opt/anaconda3/lib/python3.11/site-packages/keras/src/trainers/compile_utils.py", line 17, in update_state
#
#   File "/opt/anaconda3/lib/python3.11/site-packages/keras/src/metrics/reduction_metrics.py", line 204, in update_state
#
#   File "/opt/anaconda3/lib/python3.11/site-packages/keras/src/metrics/accuracy_metrics.py", line 240, in sparse_categorical_accuracy
#
#   File "/opt/anaconda3/lib/python3.11/site-packages/keras/src/ops/numpy.py", line 869, in argmax
#
#   File "/opt/anaconda3/lib/python3.11/site-packages/keras/src/backend/tensorflow/numpy.py", line 772, in argmax
#
# Reduction axis -1 is empty in shape [40,0]
# 	 [[{{node ArgMax}}]] [Op:__inference_one_step_on_iterator_751325]

# %%
# Evaluate the model
loss, accuracy = model.evaluate(X_test, y_test)
print(f'Loss: {loss}')
print(f'Accuracy: {accuracy}')
# Out:
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - accuracy: 0.1103 - loss: 12.7256
# Loss: 12.760379791259766
# Accuracy: 0.11666666716337204

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# Example tokenizers (replace with your actual tokenizers)
text_tokenizer = Tokenizer()  # You should have fitted this tokenizer on your training data
label_tokenizer = Tokenizer()  # You should have fitted this tokenizer on your labels

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.sequence import pad_sequences
import pickle

# Define file paths
model_path = 'language_detection_model.h5'
label_tokenizer_path = 'label_tokenizer.pkl'
tokenizer_path = 'text_tokenizer.pkl'

# Load the model and tokenizers
try:
    model = tf.keras.models.load_model(model_path)
    with open(label_tokenizer_path, 'rb') as handle:
        label_tokenizer = pickle.load(handle)
    with open(tokenizer_path, 'rb') as handle:
        tokenizer = pickle.load(handle)
except Exception as e:
    print(f"Error loading model or tokenizer: {e}")

# Define the prediction function
def predict_language(sentence, maxlen):
    sequences = tokenizer.texts_to_sequences([sentence])
    padded_sequences = pad_sequences(sequences, maxlen=maxlen)
    
    # Predict the language
    prediction = model.predict(padded_sequences)
    predicted_label_index = np.argmax(prediction, axis=1)[0]
    predicted_label = label_tokenizer.index_word.get(predicted_label_index + 1, 'Unknown')

    return predicted_label

# Example usage
maxlen = 100  # Ensure this is consistent with the padding length used during training
sentence = "re go bona kamoo o hudugago ka gona"
print(predict_language(sentence, maxlen))
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step
# tsn

# %%
from keras.models import load_model, Sequential
import pickle

# Assuming model is a Keras model
# Convert model to .h5 format
model.save('kgoza.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
